# %%
3*3
# Out:
# 9

# %%
a=30
for i in range(1):
    print("test-", i  ,"-hoge")

# %%
#必要なライブラリの利用を宣言する
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
# グラフを描画
x = np.arange(0,200,10)
y = np.cos(x)
plt.plot(x,y)
plt.show()

# %%
0.787/0.95
# Out:
# 0.8284210526315791

# %%
import math
math.sqrt(float(Out[21]))
# Out:
# 0.9101763854504131

# %%
1-(1-float(Out[22]))**2
# Out:
# 0.9919317182692472

# %%
float(Out[23])*0.9*0.9
# Out:
# 0.8034646917980903

# %%
0.95**2*float(Out[9])
# Out:
# 0.8307748642081079
